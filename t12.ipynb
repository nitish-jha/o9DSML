# %%
_sales = "select ([WalmartTime].[Day] * [Version].[Version Name].[CurrentWorkingView]  * [Department].[Department_ID].[1] * [Store].[Store_ID] * {Measure.[Weekly Sales]}  );"

import os
env = os.environ

env['o9_web_api_url'] = 'https://mygenieazure.o9solutions.com'
env['o9_auth_token'] = '1bta34kxyvxcxpdqbuot30xw'
env['local_host'] = 'http://localhost:8000'
env['o9_tenant_name'] = 'qarelease_pyplatformhivetest'
print("done")

print(env)


# Initialize the O9DataLake with the input parameters and dataframes
# Data can be accessed with O9DataLake.get(<Input Name>)
# Overwritten values will not be reflected in the O9DataLake after initialization

from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
O9DataLake.register("sales",DataSource.LS, ResourceType.IBPL, _sales)
# Out:
# done
# environ({'USER': 'user', 'JUPYTERHUB_HOST': '', 'JUPYTERHUB_USER': 'user', 'HOME': '/home/user', 'JUPYTERHUB_OAUTH_CALLBACK_URL': '/user/user/oauth_callback', 'JUPYTERHUB_API_URL': 'http://127.0.0.1:8081/hub/api', 'JUPYTERHUB_CLIENT_ID': 'jupyterhub-user-user', 'PATH': '/home/user/anaconda3/envs/jhub/bin:/home/user/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/WindowsApps/CanonicalGroupLimited.UbuntuonWindows_2004.2022.1.0_x64__79rhkp1fndgsc:/mnt/c/Program Files (x86)/Microsoft SDKs/Azure/CLI2/wbin:/mnt/c/Windows/system32:/mnt/c/Windows:/mnt/c/Windows/System32/Wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0:/mnt/c/Windows/System32/OpenSSH:/mnt/c/Program Files/PuTTY:/mnt/c/Program Files/dotnet:/mnt/c/Program Files/Microsoft SQL Server/130/Tools/Binn:/mnt/c/Program Files/Microsoft SQL Server/Client SDK/ODBC/170/Tools/Binn:/mnt/c/Program Files (x86)/Microsoft SQL Server/130/DTS/Binn:/mnt/c/Program Files/Microsoft SQL Server/130/DTS/Binn:/mnt/c/Program Files/Microsoft SQL Server/Client SDK/ODBC/130/Tools/Binn:/mnt/c/Program Files (x86)/Microsoft SQL Server/130/Tools/Binn:/mnt/c/Program Files (x86)/Microsoft SQL Server/Client SDK/ODBC/130/Tools/Binn:/mnt/c/Program Files (x86)/Microsoft SQL Server/130/Tools/Binn/ManagementStudio:/mnt/c/Program Files/RedHat/java-1.8.0-openjdk-1.8.0.312-2/bin:/mnt/c/Program Files/RedHat/java-1.8.0-openjdk-1.8.0.312-2/jre/bin:/mnt/c/Program Files/Go/bin:/mnt/c/Program Files (x86)/dotnet:/mnt/c/Program Files/Docker/Docker/resources/bin:/mnt/c/ProgramData/DockerDesktop/version-bin:/mnt/c/Program Files (x86)/NVIDIA Corporation/PhysX/Common:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/gagan.dhakar/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/gagan.dhakar/.dotnet/tools:/mnt/c/Program Files (x86)/Sophos/Sophos SSL VPN Client/bin:/mnt/c/apps/spark-3.0.0-bin-hadoop2.7/bin:/mnt/c/Users/gagan.dhakar/go/bin:/mnt/c/Users/gagan.dhakar/AppData/Local/Programs/mongosh:/mnt/c/Users/gagan.dhakar/AppData/Local/Google/Cloud SDK/google-cloud-sdk/bin:/snap/bin', 'JUPYTERHUB_ACTIVITY_URL': 'http://127.0.0.1:8081/hub/api/users/user/activity', 'LANG': 'C.UTF-8', 'SHELL': '/bin/bash', 'CONDA_DEFAULT_ENV': 'jhub', 'JUPYTERHUB_SERVICE_PREFIX': '/user/user/', 'JUPYTERHUB_API_TOKEN': '8cc129a1fa4243d7a7b94e7ab2bcc491', 'PWD': '/home/user', 'JUPYTERHUB_SERVER_NAME': '', 'JUPYTERHUB_BASE_URL': '/', 'JPY_API_TOKEN': '8cc129a1fa4243d7a7b94e7ab2bcc491', 'GIT_PYTHON_REFRESH': 'quiet', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'JPY_PARENT_PID': '4163', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'o9_web_api_url': 'https://mygenieazure.o9solutions.com', 'o9_auth_token': '1bta34kxyvxcxpdqbuot30xw', 'local_host': 'http://localhost:8000', 'o9_tenant_name': 'qarelease_pyplatformhivetest'})

# %%
import os
import numpy as np
import pandas as pd 
import logging
from o9_common_utils.O9DataLake import O9DataLake
# Initializing logger

logger = logging.getLogger('o9_logger')
logger.info("WMLogger: Reading Input Dataframes")


sales_df = O9DataLake.get('sales')

logger.info("Sales:")
logger.info(sales_df.head())

sales_df["PredictedSales"] = np.arange(sales_df.shape[0])

output = sales_df.copy(deep=True)
output["PredictedSales"] = 0

output = output.astype({'PredictedSales':'float64'})

logger.info("Output:")
logger.info(output.head())
O9DataLake.put("output", output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1236/757574743.py in <module>
#      13
#      14 logger.info("Sales:")
# ---> 15 logger.info(sales_df.head())
#      16
#      17 sales_df["PredictedSales"] = np.arange(sales_df.shape[0])
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
logging.info("WMLogger: Finishing Plugin Execution")
